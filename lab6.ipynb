# %% [markdown]
# # Лабораторная 6

# %% [markdown]
# ## Оценка сложности алгоритмов

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_06_02_01.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


def foo(a):
    """!!!

    Сложность: O(N^2).
    """
    for i in range(len(a), 0, -1):
        for j in range(1, i):
            if a[j-1] > a[j]:
                a[j-1], a[j] = a[j], a[j-1]
    return a


a = [1, 2, 3, 4, 2, 1, 3, 4, 3, 5, -2, -2, 2, -2, 65, 2, 2]
foo(a)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_06_02_02.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


def foo(i):
    """!!!

    Параметры:
        - i (int): число.

    Сложность: O(N).
    """
    digits = "0123456789"
    if i == 0:
        return "0"
    result = ""
    while i > 0:
        result = digits[i%10] + result
        i = i // 10
    return result

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_06_02_03.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


def foo(s):
    """!!!

    Параметры:
        - s (str): строка.

    Сложность: O(N).
    """
    val = 0
    for c in s:
        if c.isdigit():
            val += int(c)
    return val

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_06_02_04.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


def foo(n):
    """!!!

    Параметры:
        - n (int): число.

    Сложность: O(NlogN).
    """
    res = []
    for i in range(1, n + 1):
        divisors = 0
        j = 2
        while j < i and divisors == 0:
            if i % j == 0:
                divisors += 1
            j += 1

        if divisors == 0:
            res.append(i)

    return res

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_06_02_05.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


def foo(nums):
    """!!!

    Параметры:
        - nums (list): список.

    Сложность: O(NlogN).
    """
    for x in nums:
        if x % 2 == 0:
            return True
    else:
        return False

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_06_02_06.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


def foo(nums):
    """!!!

    Параметры:
        - nums (list): список.

    Сложность: O(1).
    """
    return (nums[0] + nums[-1] ** 2)

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_06_02_07.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


def foo(low, high):
    """!!!

    Параметры:
        - low (int): нижняя граница;
        - high (int): верхняя граница.

    Сложность: O(logN).
    """
    guessing = True
    while guessing:
        guess = (low + high) // 2
        print("Загаданное число {0}?".format(guess))
        pointer = input(
            "Введите '+', если Ваше число меньше.\n"
            "Введите '-' если Ваше число больше.\n"
            "Введите '=', если я угадал.\n").lower()
        if pointer == "+":
            high = guess
        elif pointer == "-":
            low = guess
        elif pointer == "=":
            guessing = False
        else:
            print("Введите '+', '-' или '='.")

    return guess


low, high = 0, 100
print("Пожалуйста, загадайте число от {0} до {1}!".format(low, high))
guess = foo(low, high)
print("Игра окончена, Вы загадали число: {0}.".format(guess))
# Out:
# Пожалуйста, загадайте число от 0 до 100!
# Загаданное число 50?
# Введите '+', если Ваше число меньше.
# Введите '-' если Ваше число больше.
# Введите '=', если я угадал.
# -
# Загаданное число 75?
# Введите '+', если Ваше число меньше.
# Введите '-' если Ваше число больше.
# Введите '=', если я угадал.
# +
# Загаданное число 62?
# Введите '+', если Ваше число меньше.
# Введите '-' если Ваше число больше.
# Введите '=', если я угадал.
# -
# Загаданное число 68?
# Введите '+', если Ваше число меньше.
# Введите '-' если Ваше число больше.
# Введите '=', если я угадал.
# -
# Загаданное число 71?
# Введите '+', если Ваше число меньше.
# Введите '-' если Ваше число больше.
# Введите '=', если я угадал.
# +
# Загаданное число 69?
# Введите '+', если Ваше число меньше.
# Введите '-' если Ваше число больше.
# Введите '=', если я угадал.
# -
# Загаданное число 70?
# Введите '+', если Ваше число меньше.
# Введите '-' если Ваше число больше.
# Введите '=', если я угадал.
# =
# Игра окончена, Вы загадали число: 70.

# %% [markdown]
# ## Сравнение сложности алгоритмов

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_06_02_08.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


import random
import time


def timeit(func, *args, **kw):
    """Выполнить функицю 'func' с параметрами '*args', '**kw' и
    вернуть время выполнения в мс."""

    time_start = time.time()
    res = func(*args, **kw)
    time_end = time.time()

    return (time_end - time_start) * 1000.0, res


def maxmin1(data):
    """Вернуть минимум и максимум из 'data'.

    Алгоритм:
        Последовательный перебор всего массива.

    Сложность: O(N).

    Параметры:
        - data (list of int): список целых чисел.

    Результат:
        tuple: мин. и макс. значения."""

    min_n = 1000000
    max_n = 0
    for i in data:
      if i > max_n:
        max_n = i
      if i < min_n:
        min_n = i
    return (min_n, max_n)


def maxmin2(data):
    """Вернуть минимум и максимум из 'data'.

    Алгоритм:
        Сортировка списка, и возврат первого и последнего элементов.

    Сложность: O(NlogN).

    Параметры:
        - data (list of int): список целых чисел.

    Результат:
        tuple: мин. и макс. значения."""

    data.sort()
    min_n = data[0]
    max_n = data[len(data) - 1]
    return (min_n, max_n)



def maxmin3(data):
    """Вернуть минимум и максимум из 'data'.

    Алгоритм:
        Используя встроенные функции min() и max().

    Сложность: O(N).

    Параметры:
        - data (list of int): список целых чисел.

    Результат:
        tuple: мин. и макс. значения."""

    mim_n = min(data)
    max_n = max(data)


if __name__ == "__main__":
    GEN_LIMIT = 1000000
    dataset = []
    for i in range(4, 7):
        dataset.append(random.sample(range(-GEN_LIMIT, GEN_LIMIT), 10**i))

    res = [["i", "1 способ (мс.)", "2 способ (мс.)", "3 способ (мс.)"]]
    for data in dataset:
        res.append([len(data),
                   timeit(maxmin1, data)[0],
                   timeit(maxmin2, data)[0],
                   timeit(maxmin3, data)[0]])

    # Вывод
    print("{:>15} {:>15} {:>15} {:>15}".format(*res[0]))
    for r in res[1:]:
        print("{:>15} {:>15.2f} {:>15.2f} {:>15.2f}".format(*r))

# -------------
# Пример вывода:
#
#              i  1 способ (мс.)  2 способ (мс.)  3 способ (мс.)
#          10000            1.00            5.00            0.00
#            ...
# Out:
#               i  1 способ (мс.)  2 способ (мс.)  3 способ (мс.)
#           10000            0.81            2.89            0.35
#          100000            5.80           45.57           10.07
#         1000000          156.01          790.37           39.30

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_06_02_09.
#
# Выполнил: Фамилия И.О.
# Группа: !!!
# E-mail: !!!


import random
import time


def timeit(func, *args, **kw):
    """Выполнить функицю 'func' с параметрами '*args', '**kw' и
    вернуть время выполнения в мс."""

    time_start = time.time()
    res = func(*args, **kw)
    time_end = time.time()

    return (time_end - time_start) * 1000.0, res


def is_ok_to_pass_1(db, passport_id):
    """Вернуть отметку о допуске из 'db' для паспорта с номером 'passport_id'.

    Если паспорт не найден в базе данных, возвращается отказ в допуске.

    Алгоритм:
        Последовательный перебор списка.

    Сложность: O(N).

    Параметры:
        - db (list of dict): база данных;
        - passport_id (str): номер паспорта.

    Результат:
        bool: отметка о допуске."""
    for pas in db:
      if pas.get('id') == passport_id:
        return pas.get('ok')



def is_ok_to_pass_2(db_opt, passport_id):
    """Вернуть отметку о допуске из 'db_opt' для паспорта с номером 'passport_id'.

    Если паспорт не найден в базе данных, возвращается отказ в допуске.

    Алгоритм:
        # !!!.

    Сложность: O(N).

    Параметры:
        - db_opt (dict): оптимизированная база данных для поиска;
        - passport_id (str): номер паспорта.

    Результат:
        bool: отметка о допуске."""
    for pas in db_opt:
      if pas.get('id') == passport_id:
        return pas.get('ok')


def ok_str(flag):
    return "Да" if flag else "Нет"


if __name__ == "__main__":
    print("Загрузка базы данных... ")

    GEN_LIMIT = 1000000
    # База данных
    db = [{"id": "{:07d}".format(i), "ok": random.random() < 0.9}
          for i in random.sample(range(GEN_LIMIT, 10 * GEN_LIMIT), GEN_LIMIT)]

    # Структура db_opt должна быть оптимизированным хранилищем
    db_opt = sorted(db, key=lambda k: k['id'])

    print("Загружено записей: {:,}.\n\nПримеры:".format(GEN_LIMIT))
    print("Первый элемент:", db[0])
    print("Последний элемент:", db[-1])
    print("\n")

    passport_id = input("Введите номер паспорта (7 цифр): ").strip()

    output = """
                  1 способ   2 способ
    Допущен     {:>10s} {:>10s}
    Время (мс.) {:>10.2f} {:>10.2f}\
    """

    res1 = timeit(is_ok_to_pass_1, db, passport_id)
    res2 = timeit(is_ok_to_pass_2, db_opt, passport_id)

    print(output.format(ok_str(res1[1]),
                        ok_str(res2[1]),
                        res1[0],
                        res2[0]))

# -------------
# Пример вывода:
#
# Загрузка базы данных...
# Загружено записей: 1,000,000.
#
# Примеры:
# Первый элемент: {'ok': True, 'id': '4998753'}
# Последний элемент: {'ok': True, 'id': '6280964'}
#
#
# Введите номер паспорта (7 цифр): 6280964
#
#               1 способ   2 способ
# Допущен             Да         Да
# Время (мс.)     145.10       0.00
# Out:
# Загрузка базы данных...
# Загружено записей: 1,000,000.
#
# Примеры:
# Первый элемент: {'id': '4626702', 'ok': True}
# Последний элемент: {'id': '3851212', 'ok': True}
#
#
# Введите номер паспорта (7 цифр): 1000000
#
#                   1 способ   2 способ
#     Допущен             Да         Да
#     Время (мс.)      43.37       0.00
